# %% [markdown]
# # Fifa Soccer Players #

# %% [markdown]
# ## Import packages and explore dataset ##

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('fifa_soccer_players.csv')
df.head()
# Out:
#    sofifa_id                            long_name  age         dob  height_cm  \
# 0     158023       Lionel Andrés Messi Cuccittini   33  1987-06-24        170
# 1      20801  Cristiano Ronaldo dos Santos Aveiro   35  1985-02-05        187
# 2     200389                            Jan Oblak   27  1993-01-07        188
# 3     188545                   Robert Lewandowski   31  1988-08-21        184
# 4     190871        Neymar da Silva Santos Júnior   28  1992-02-05        175
#
#    weight_kg nationality            club_name             league_name  \
# 0         72   Argentina         FC Barcelona  Spain Primera Division
# 1         83    Portugal             Juventus         Italian Serie A
# 2         87    Slovenia      Atlético Madrid  Spain Primera Division
# 3         80      Poland    FC Bayern München    German 1. Bundesliga
# 4         68      Brazil  Paris Saint-Germain          French Ligue 1
#
#   player_positions  ...  defending  gk_diving  gk_handling  gk_kicking  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18944 entries, 0 to 18943
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sofifa_id         18944 non-null  int64
#  1   long_name         18944 non-null  object
#  2   age               18944 non-null  int64
#  3   dob               18944 non-null  object
#  4   height_cm         18944 non-null  int64
#  5   weight_kg         18944 non-null  int64
#  6   nationality       18944 non-null  object
#  7   club_name         18719 non-null  object
#  8   league_name       18719 non-null  object
#  9   player_positions  18944 non-null  object
#  10  potential         18944 non-null  int64
#  11  pace              16861 non-null  float64
#  12  shooting          16861 non-null  float64
#  13  passing           16861 non-null  float64
#  14  dribbling         16861 non-null  float64
#  15  defending         16861 non-null  float64
# ...

# %%
teams = df.groupby(['league_name', 'club_name'])

# %%
teams

# %%
teams = teams[['league_name', 'club_name','long_name','nationality','age', 'overall_rating']]
teams.head()
# Out:
#                           league_name            club_name  \
# 0              Spain Primera Division         FC Barcelona
# 1                     Italian Serie A             Juventus
# 2              Spain Primera Division      Atlético Madrid
# 3                German 1. Bundesliga    FC Bayern München
# 4                      French Ligue 1  Paris Saint-Germain
# ...                               ...                  ...
# 16532  Rep. Ireland Airtricity League        Shelbourne FC
# 16597  Rep. Ireland Airtricity League           Finn Harps
# 16818  Rep. Ireland Airtricity League           Finn Harps
# 16944  Rep. Ireland Airtricity League           Finn Harps
# 17052  Rep. Ireland Airtricity League           Finn Harps
#
#                                  long_name          nationality  age  \
# 0           Lionel Andrés Messi Cuccittini            Argentina   33
# 1      Cristiano Ronaldo dos Santos Aveiro             Portugal   35
# ...

# %%
df.league_name.value_counts()
# Out:
# English League Championship             709
# USA Major League Soccer                 701
# Argentina Primera División              659
# English Premier League                  654
# Spain Primera Division                  645
# Italian Serie A                         645
# English League One                      630
# Spanish Segunda División                619
# English League Two                      605
# French Ligue 1                          600
# Turkish Süper Lig                       589
# German 1. Bundesliga                    548
# French Ligue 2                          546
# German 3. Bundesliga                    522
# Japanese J. League Division 1           521
# Portuguese Liga ZON SAGRES              510
# Mexican Liga MX                         509
# German 2. Bundesliga                    507
# Belgian Jupiler Pro League              492
# Holland Eredivisie                      466
# Chinese Super League                    436
# ...

# %%
df.long_name.unique()[0]
# Out:
# 'Lionel Andrés Messi Cuccittini'
